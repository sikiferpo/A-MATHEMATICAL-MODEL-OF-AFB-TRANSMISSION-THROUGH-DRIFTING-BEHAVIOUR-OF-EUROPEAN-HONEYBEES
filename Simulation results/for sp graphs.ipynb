# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data from the second sheet of the Excel file
excel_file = r"C:\Users\Dell\Desktop\Kieffer\UP\For thesis real\RRL\RRL synthesis.xlsx"  # Replace 'your_excel_file.xlsx' with your file path
sheet_name = 1  # Index of the second sheet (Python index starts from 0)
data = pd.read_excel(excel_file, sheet_name=sheet_name)

# Assuming your data has columns 'x' and 'y'
x = data['TIME']
y1 = data['B1:1']
y2 = data['B1a:1']
y3 = data['B1s:1']
y4 = data['C1:1']
y5 = data['A1:1']
y6 = data['A1s:1']
y7 = data['B2:1']
y8 = data['B2a:1']
y9 = data['B2s:1']
y10 = data['C2:1']
y11 = data['A2:1']
y12 = data['A2s:1']
y13 = data['A21s:1']
y14 = data['A21:1']
y15 = data['A12s:1']
y16 = data['A12:1']

fig, axs = plt.subplots(1, 2, figsize=(15,5))

# Plot the data
axs[0].plot(x, y1, label='$B_1$')
axs[0].plot(x, y2, label='$B_{1a}$')
axs[0].plot(x, y3, label='$B_{1s}$')
axs[0].plot(x, y4, label='$C_1$')
axs[0].plot(x, y5, label='$A_1$')
axs[0].plot(x, y6, label='$A_{1s}$')
axs[0].plot(x, y13, label='$A_{21s}$')
axs[0].plot(x, y14, label='$A_{21}$')
axs[0].set_xlabel('Days')
axs[0].set_ylabel('Population')
axs[0].set_title('Colony 1')
axs[0].legend(loc='lower center', bbox_to_anchor=(0.5, -0.3), shadow=True, ncol=4)

axs[1].plot(x, y7, label='$B_2$')
axs[1].plot(x, y8, label='$B_{2a}$')
axs[1].plot(x, y9, label='$B_{2s}$')
axs[1].plot(x, y10, label='$C_2$')
axs[1].plot(x, y11, label='$A_2$')
axs[1].plot(x, y12, label='$A_{2s}$')
axs[1].plot(x, y15, label='$A_{12s}$')
axs[1].plot(x, y16, label='$A_{12}$')
axs[1].set_xlabel('Days')
axs[1].set_ylabel('Population')
axs[1].set_title('Colony 2')
axs[1].legend(loc='lower center', bbox_to_anchor=(0.5, -0.3), shadow=True, ncol=4)


plt.subplots_adjust(wspace=0.5)

plt.show()

# %%
excel_file = r"C:\Users\Dell\Desktop\Kieffer\UP\For thesis real\RRL\RRL synthesis.xlsx"  # Replace 'your_excel_file.xlsx' with your file path
sheet_name = 2  # Index of the second sheet (Python index starts from 0)
data = pd.read_excel(excel_file, sheet_name=sheet_name)

# Assuming your data has columns 'x' and 'y'
x = data['TIME']
y1 = data['B1:1']
y2 = data['B1a:1']
y3 = data['B1s:1']
y4 = data['C1:1']
y5 = data['A1:1']
y6 = data['A1s:1']
y7 = data['B2:1']
y8 = data['B2a:1']
y9 = data['B2s:1']
y10 = data['C2:1']
y11 = data['A2:1']
y12 = data['A2s:1']
y13 = data['A21s:1']
y14 = data['A21:1']
y15 = data['A12s:1']
y16 = data['A12:1']

fig, axs = plt.subplots(1, 2, figsize=(15,5))

# Plot the data
axs[0].plot(x, y1, label='$B_1$')
axs[0].plot(x, y2, label='$B_{1a}$')
axs[0].plot(x, y3, label='$B_{1s}$')
axs[0].plot(x, y4, label='$C_1$')
axs[0].plot(x, y5, label='$A_1$')
axs[0].plot(x, y6, label='$A_{1s}$')
axs[0].plot(x, y13, label='$A_{21s}$')
axs[0].plot(x, y14, label='$A_{21}$')
axs[0].set_xlabel('Days')
axs[0].set_ylabel('Population')
axs[0].set_title('Colony 1')
axs[0].legend(loc='lower center', bbox_to_anchor=(0.5, -0.3), shadow=True, ncol=4)

axs[1].plot(x, y7, label='$B_2$')
axs[1].plot(x, y8, label='$B_{2a}$')
axs[1].plot(x, y9, label='$B_{2s}$')
axs[1].plot(x, y10, label='$C_2$')
axs[1].plot(x, y11, label='$A_2$')
axs[1].plot(x, y12, label='$A_{2s}$')
axs[1].plot(x, y15, label='$A_{12s}$')
axs[1].plot(x, y16, label='$A_{12}$')
axs[1].set_xlabel('Days')
axs[1].set_ylabel('Population')
axs[1].set_title('Colony 2')
axs[1].legend(loc='lower center', bbox_to_anchor=(0.5, -0.3), shadow=True, ncol=4)


plt.subplots_adjust(wspace=0.5)

plt.show()

# %%
excel_file = r"C:\Users\Dell\Desktop\Kieffer\UP\For thesis real\RRL\RRL synthesis.xlsx"  # Replace 'your_excel_file.xlsx' with your file path
sheet_name = 3  # Index of the second sheet (Python index starts from 0)
data = pd.read_excel(excel_file, sheet_name=sheet_name)

# Assuming your data has columns 'x' and 'y'
x = data['TIME']
y1 = data['B1:1']
y2 = data['B1a:1']
y3 = data['B1s:1']
y4 = data['C1:1']
y5 = data['A1:1']
y6 = data['A1s:1']
y7 = data['B2:1']
y8 = data['B2a:1']
y9 = data['B2s:1']
y10 = data['C2:1']
y11 = data['A2:1']
y12 = data['A2s:1']
y13 = data['A21s:1']
y14 = data['A21:1']
y15 = data['A12s:1']
y16 = data['A12:1']

fig, axs = plt.subplots(1, 2, figsize=(15,5))

# Plot the data
axs[0].plot(x, y1, label='$B_1$')
axs[0].plot(x, y2, label='$B_{1a}$')
axs[0].plot(x, y3, label='$B_{1s}$')
axs[0].plot(x, y4, label='$C_1$')
axs[0].plot(x, y5, label='$A_1$')
axs[0].plot(x, y6, label='$A_{1s}$')
axs[0].plot(x, y13, label='$A_{21s}$')
axs[0].plot(x, y14, label='$A_{21}$')
axs[0].set_xlabel('Days')
axs[0].set_ylabel('Population')
axs[0].set_title('Colony 1')
axs[0].legend(loc='lower center', bbox_to_anchor=(0.5, -0.3), shadow=True, ncol=4)

axs[1].plot(x, y7, label='$B_2$')
axs[1].plot(x, y8, label='$B_{2a}$')
axs[1].plot(x, y9, label='$B_{2s}$')
axs[1].plot(x, y10, label='$C_2$')
axs[1].plot(x, y11, label='$A_2$')
axs[1].plot(x, y12, label='$A_{2s}$')
axs[1].plot(x, y15, label='$A_{12s}$')
axs[1].plot(x, y16, label='$A_{12}$')
axs[1].set_xlabel('Days')
axs[1].set_ylabel('Population')
axs[1].set_title('Colony 2')
axs[1].legend(loc='lower center', bbox_to_anchor=(0.5, -0.3), shadow=True, ncol=4)


plt.subplots_adjust(wspace=0.5)

plt.show()

# %%
excel_file = r"C:\Users\Dell\Desktop\Kieffer\UP\For thesis real\RRL\RRL synthesis.xlsx"  # Replace 'your_excel_file.xlsx' with your file path
sheet_name = 4  # Index of the second sheet (Python index starts from 0)
data = pd.read_excel(excel_file, sheet_name=sheet_name)

# Assuming your data has columns 'x' and 'y'
x = data['TIME']
y1 = data['B1:1']
y2 = data['B1a:1']
y3 = data['B1s:1']
y4 = data['C1:1']
y5 = data['A1:1']
y6 = data['A1s:1']
y7 = data['B2:1']
y8 = data['B2a:1']
y9 = data['B2s:1']
y10 = data['C2:1']
y11 = data['A2:1']
y12 = data['A2s:1']
y13 = data['A21s:1']
y14 = data['A21:1']
y15 = data['A12s:1']
y16 = data['A12:1']

fig, axs = plt.subplots(1, 2, figsize=(15,5))

# Plot the data
axs[0].plot(x, y1, label='$B_1$')
axs[0].plot(x, y2, label='$B_{1a}$')
axs[0].plot(x, y3, label='$B_{1s}$')
axs[0].plot(x, y4, label='$C_1$')
axs[0].plot(x, y5, label='$A_1$')
axs[0].plot(x, y6, label='$A_{1s}$')
axs[0].plot(x, y13, label='$A_{21s}$')
axs[0].plot(x, y14, label='$A_{21}$')
axs[0].set_xlabel('Days')
axs[0].set_ylabel('Population')
axs[0].set_title('Colony 1')
axs[0].legend(loc='lower center', bbox_to_anchor=(0.5, -0.3), shadow=True, ncol=4)

axs[1].plot(x, y7, label='$B_2$')
axs[1].plot(x, y8, label='$B_{2a}$')
axs[1].plot(x, y9, label='$B_{2s}$')
axs[1].plot(x, y10, label='$C_2$')
axs[1].plot(x, y11, label='$A_2$')
axs[1].plot(x, y12, label='$A_{2s}$')
axs[1].plot(x, y15, label='$A_{12s}$')
axs[1].plot(x, y16, label='$A_{12}$')
axs[1].set_xlabel('Days')
axs[1].set_ylabel('Population')
axs[1].set_title('Colony 2')
axs[1].legend(loc='lower center', bbox_to_anchor=(0.5, -0.3), shadow=True, ncol=4)


plt.subplots_adjust(wspace=0.5)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Read Data from Excel
excel_file = r"C:\Users\Dell\Desktop\Kieffer\UP\For thesis real\RRL\RRL synthesis.xlsx"  # Replace 'your_excel_file.xlsx' with your file path
sheet_name = 5  # Index of the second sheet (Python index starts from 0)
data = pd.read_excel(excel_file, sheet_name=sheet_name)

# Step 2: Extract Column Labels and Split Data into Even and Odd Columns
columns = data.columns
time_column = columns[0]  # Assuming the first column is the time column
data_columns = columns[1:]  # Extracting other columns
even_columns = data_columns[::2]  # Select even columns
odd_columns = data_columns[1::2]  # Select odd columns

# Step 3: Plotting - Side by Side
fig, axs = plt.subplots(1, 2, figsize=(15, 5))  # Adjust figure size if needed

# Plot even columns
for column in even_columns:
    axs[0].plot(data[time_column], data[column], label=column)

axs[0].set_xlabel('Time')
axs[0].set_ylabel('Population')
axs[0].set_title('Healthy Adult Honeybees in Colony 1')
axs[0].legend()
axs[0].grid(False)

# Plot odd columns
for column in odd_columns:
    axs[1].plot(data[time_column], data[column], label=column)

axs[1].set_xlabel('Time')
axs[1].set_ylabel('Population')
axs[1].set_title('Healthy Adult Honeybees in Colony 2')
axs[1].legend()
axs[1].grid(False)

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.3)  # Adjust the width space between subplots

plt.show()

# %%
# Step 1: Read Data from Excel
excel_file = r"C:\Users\Dell\Desktop\Kieffer\UP\For thesis real\RRL\RRL synthesis.xlsx"  # Replace 'your_excel_file.xlsx' with your file path
sheet_name = 6  # Index of the second sheet (Python index starts from 0)
data = pd.read_excel(excel_file, sheet_name=sheet_name)

# Step 2: Extract Column Labels and Split Data into Even and Odd Columns
columns = data.columns
time_column = columns[0]  # Assuming the first column is the time column
data_columns = columns[1:]  # Extracting other columns
even_columns = data_columns[::2]  # Select even columns
odd_columns = data_columns[1::2]  # Select odd columns

# Step 3: Plotting - Side by Side
fig, axs = plt.subplots(1, 2, figsize=(15, 5))  # Adjust figure size if needed

# Plot even columns
for column in even_columns:
    axs[0].plot(data[time_column], data[column], label=column)

axs[0].set_xlabel('Time')
axs[0].set_ylabel('Population')
axs[0].set_title('Healthy Adult Honeybees in Colony 1')
axs[0].legend()
axs[0].grid(False)

# Plot odd columns
for column in odd_columns:
    axs[1].plot(data[time_column], data[column], label=column)

axs[1].set_xlabel('Time')
axs[1].set_ylabel('Population')
axs[1].set_title('Healthy Adult Honeybees in Colony 2')
axs[1].legend()
axs[1].grid(False)

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.3)  # Adjust the width space between subplots

plt.show()

# %%
# Step 1: Read Data from Excel
excel_file = r"C:\Users\Dell\Desktop\Kieffer\UP\For thesis real\RRL\RRL synthesis.xlsx"  # Replace 'your_excel_file.xlsx' with your file path
sheet_name = 7  # Index of the second sheet (Python index starts from 0)
data = pd.read_excel(excel_file, sheet_name=sheet_name)

# Step 2: Extract Column Labels and Split Data into Even and Odd Columns
columns = data.columns
time_column = columns[0]  # Assuming the first column is the time column
data_columns = columns[1:]  # Extracting other columns
even_columns = data_columns[::2]  # Select even columns
odd_columns = data_columns[1::2]  # Select odd columns

# Step 3: Plotting - Side by Side
fig, axs = plt.subplots(1, 2, figsize=(15, 5))  # Adjust figure size if needed

# Plot even columns
for column in even_columns:
    axs[0].plot(data[time_column], data[column], label=column)

axs[0].set_xlabel('Time')
axs[0].set_ylabel('Population')
axs[0].set_title('Healthy Adult Honeybees in Colony 1')
axs[0].legend()
axs[0].grid(False)

# Plot odd columns
for column in odd_columns:
    axs[1].plot(data[time_column], data[column], label=column)

axs[1].set_xlabel('Time')
axs[1].set_ylabel('Population')
axs[1].set_title('Healthy Adult Honeybees in Colony 2')
axs[1].legend()
axs[1].grid(False)

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.3)  # Adjust the width space between subplots

plt.show()

# %%
# Step 1: Read Data from Excel
excel_file = r"C:\Users\Dell\Desktop\Kieffer\UP\For thesis real\RRL\RRL synthesis.xlsx"  # Replace 'your_excel_file.xlsx' with your file path
sheet_name = 8  # Index of the second sheet (Python index starts from 0)
data = pd.read_excel(excel_file, sheet_name=sheet_name)

# Step 2: Extract Column Labels and Split Data into Even and Odd Columns
columns = data.columns
time_column = columns[0]  # Assuming the first column is the time column
data_columns = columns[1:]  # Extracting other columns
even_columns = data_columns[::2]  # Select even columns
odd_columns = data_columns[1::2]  # Select odd columns

# Step 3: Plotting - Side by Side
fig, axs = plt.subplots(1, 2, figsize=(15, 5))  # Adjust figure size if needed

# Plot even columns
for column in even_columns:
    axs[0].plot(data[time_column], data[column], label=column)

axs[0].set_xlabel('Time')
axs[0].set_ylabel('Population')
axs[0].set_title('Healthy Adult Honeybees in Colony 1')
axs[0].legend()
axs[0].grid(False)

# Plot odd columns
for column in odd_columns:
    axs[1].plot(data[time_column], data[column], label=column)

axs[1].set_xlabel('Time')
axs[1].set_ylabel('Population')
axs[1].set_title('Healthy Adult Honeybees in Colony 2')
axs[1].legend()
axs[1].grid(False)

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.3)  # Adjust the width space between subplots

plt.show()

# %%
# Step 1: Read Data from Excel
excel_file = r"C:\Users\Dell\Desktop\Kieffer\UP\For thesis real\RRL\RRL synthesis.xlsx"  # Replace 'your_excel_file.xlsx' with your file path
sheet_name = 9  # Index of the second sheet (Python index starts from 0)
data = pd.read_excel(excel_file, sheet_name=sheet_name)

# Step 2: Extract Column Labels and Split Data into Even and Odd Columns
columns = data.columns
time_column = columns[0]  # Assuming the first column is the time column
data_columns = columns[1:]  # Extracting other columns
even_columns = data_columns[::2]  # Select even columns
odd_columns = data_columns[1::2]  # Select odd columns

# Step 3: Plotting - Side by Side
fig, axs = plt.subplots(1, 2, figsize=(15, 5))  # Adjust figure size if needed

# Plot even columns
for column in even_columns:
    axs[0].plot(data[time_column], data[column], label=column)

axs[0].set_xlabel('Time')
axs[0].set_ylabel('Population')
axs[0].set_title('Healthy Adult Honeybees in Colony 1')
axs[0].legend(loc='lower center', bbox_to_anchor=(0.5, -0.45), shadow=True, ncol=2)
axs[0].grid(False)

# Plot odd columns
for column in odd_columns:
    axs[1].plot(data[time_column], data[column], label=column)

axs[1].set_xlabel('Time')
axs[1].set_ylabel('Population')
axs[1].set_title('Healthy Adult Honeybees in Colony 2')
axs[1].legend(loc='lower center', bbox_to_anchor=(0.5, -0.45), shadow=True, ncol=2)
axs[1].grid(False)

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.3)  # Adjust the width space between subplots

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
L1 = 1500
L2 = 1500
w1 = 21000
w2 = 21000
beta1 = 1/3
beta2 = 1/17
alpha1 = 0.001
phi1 = 1/3
phi2 = 1
v = 10000
sigma = 0.001
alpha2 = 1
alpha3 = 0.0005
mu = 1/30
d1 = 0.003
d2 = 0.003
gamma1 = 0.7
gamma2 = 0.7
re1 = 0.64
re2 = 0.64

# Define initial conditions
init_conditions = [0, 0, 0, 0, 10000, 0, 0, 0, 0, 0, 10000, 1, 0, 0, 0, 0]

# Define time parameters
STARTTIME = 0
STOPTIME = 365
DT = 0.02
num_steps = int((STOPTIME - STARTTIME) / DT)

# Define RK4 method
def rk4(f, t, y, dt):
    k1 = np.array(f(t, y))
    k2 = np.array(f(t + 0.5*dt, y + 0.5*dt*k1))
    k3 = np.array(f(t + 0.5*dt, y + 0.5*dt*k2))
    k4 = np.array(f(t + dt, y + dt*k3))
    return y + (dt/6)*(k1 + 2*k2 + 2*k3 + k4)

# Define the system of differential equations
def model(t, y):
    B1s, B1, B1a, C1, A1, A1s, B2s, B2, B2a, C2, A2, A2s, A21s, A21, A12s, A12 = y

    M1 = L1*((A1+A1s+A21+A21s)/(w1+A1+A1s+A21+A21s))
    P1 = (A1s+A21s)/(1+A1+A1s+A21+A21s)

    M2 = L2*((A2+A2s+A12+A12s)/(w2+A2+A2s+A12+A12s))
    P2 = (A2s+A12s)/(1+A2+A2s+A12+A12s)

    dB1s_dt = (alpha1*P1*B1)+(C1/v)*M1-(phi1*phi2*B1s)
    dB1_dt = M1-(alpha1*P1*B1)-(C1/v)*M1-beta1*B1
    dB1a_dt = (beta1*B1)-(beta2*B1a)
    dC1_dt = (phi1*phi2*B1s)*(sigma*(v-C1))
    dA1s_dt = (beta2*alpha1*P1*B1a)+(alpha2*(C1/v)*A1)+(alpha3*P1*A1)-(mu*A1s)-(d1*A1s)+(re1*gamma1*d1*A1s)
    dA1_dt = beta2*(1-alpha1*P1)*B1a-(alpha2*(C1/v)*A1)-(alpha3*P1*A1)-(mu*A1)-(d1*A1)+(re1*gamma1*d1*A1)

    dB2s_dt = (alpha1*P2*B2)+(C2/v)*M2-(phi1*phi2*B2s)
    dB2_dt = M2-(alpha1*P2*B2)-(C2/v)*M2-beta1*B2
    dB2a_dt = (beta1*B2)-(beta2*B2a)
    dC2_dt = (phi1*phi2*B2s)*(sigma*(v-C2))
    dA2s_dt = (beta2*alpha1*P2*B2a)+(alpha2*(C2/v)*A2)+(alpha3*P2*A2)-(mu*A2s)-(d2*A2s)+(re2*gamma2*d2*A2s)
    dA2_dt = beta2*(1-alpha1*P2)*B2a-(alpha2*(C2/v)*A2)-(alpha3*P2*A2)-(mu*A2)-(d2*A2)+(re2*gamma2*d2*A2)

    dA21s_dt = (d2*A2s)-(gamma2*d2*A2s)-mu*A21s+(alpha2*(C1/v)*A21)+(alpha3*P1*A21)
    dA21_dt = (d2*A2)-(gamma2*d2*A2)-mu*A21-(alpha2*(C1/v)*A21)-(alpha3*P1*A21)
    dA12s_dt = (d1*A1s)-(gamma1*d1*A1s)-mu*A12s+(alpha2*(C2/v)*A12)+(alpha3*P2*A12)
    dA12_dt = (d1*A1)-(gamma1*d1*A1)-mu*A12-(alpha2*(C2/v)*A12)-(alpha3*P2*A12)

    return [dB1s_dt, dB1_dt, dB1a_dt, dC1_dt, dA1_dt, dA1s_dt, dB2s_dt, dB2_dt, dB2a_dt, dC2_dt, dA2_dt, dA2s_dt, dA21s_dt, dA21_dt, dA12s_dt, dA12_dt]

# Initialize arrays to store results
t_values = np.zeros(num_steps+1)
y_values = np.zeros((num_steps+1, len(init_conditions)))

# Set initial conditions
t_values[0] = STARTTIME
y_values[0] = init_conditions

# Time integration using RK4
for i in range(num_steps):
    t = t_values[i]
    y = y_values[i]
    y_next = rk4(model, t, y, DT)
    t_values[i+1] = t + DT
    y_values[i+1] = y_next

# Plotting
plt.plot(t_values, y_values[:, 4], label='A1')
plt.plot(t_values, y_values[:, 10], label='A2')
plt.xlabel('Time')
plt.ylabel('Population')
plt.title('Population Dynamics over Time')
plt.legend()
plt.show()

# %%
import pandas as pd

# Create a DataFrame for the results
results_df = pd.DataFrame({'Time': t_values, 'A1': y_values[:, 4], 'A2': y_values[:, 10]})

# Display the DataFrame
print(results_df)
# Out:
#          Time            A1            A2
# 0        0.00  10000.000000  10000.000000
# 1        0.02   9993.004594   9993.004584
# 2        0.04   9986.014157   9986.014137
# 3        0.06   9979.028760   9979.028731
# 4        0.08   9972.048475   9972.048435
# ...       ...           ...           ...
# 18246  364.92      0.000039      0.000012
# 18247  364.94      0.000039      0.000012
# 18248  364.96      0.000039      0.000012
# 18249  364.98      0.000039      0.000012
# 18250  365.00      0.000039      0.000012
#
# [18251 rows x 3 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

# Define range of d1 and d2 values
d1_values = np.linspace(0.001, 0.01, 10)
d2_values = np.linspace(0.001, 0.01, 10)

# Initialize array to store last values of A1 and A2
last_A1_values = np.zeros((len(d1_values), len(d2_values)))
last_A2_values = np.zeros((len(d1_values), len(d2_values)))

# Loop over d1 and d2 values
for i, d1 in enumerate(d1_values):
    for j, d2 in enumerate(d2_values):
        # Define initial conditions
        init_conditions = [0, 0, 0, 0, 10000, 0, 0, 0, 0, 0, 10000, 1, 0, 0, 0, 0]

        # Define time parameters
        STARTTIME = 0
        STOPTIME = 365
        DT = 0.02
        num_steps = int((STOPTIME - STARTTIME) / DT)

        # Time integration using RK4
        t_values = np.linspace(STARTTIME, STOPTIME, num_steps+1)
        y_values = np.zeros((num_steps+1, len(init_conditions)))
        t_values[0] = STARTTIME
        y_values[0] = init_conditions
        for step in range(num_steps):
            t = t_values[step]
            y = y_values[step]
            y_next = rk4(model, t, y, DT)
            t_values[step+1] = t + DT
            y_values[step+1] = y_next

        # Store last values of A1 and A2
        last_A1_values[i, j] = y_values[-1, 4]
        last_A2_values[i, j] = y_values[-1, 10]

# Determine the maximum and minimum values for the color bar
vmin = min(np.min(last_A1_values), np.min(last_A2_values))
vmax = max(np.max(last_A1_values), np.max(last_A2_values))

# Create normalization object
norm = Normalize(vmin=vmin, vmax=vmax)

cmap = 'Accent'  # Change this to the desired colormap

# Create heatmaps with the same color bar
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.imshow(last_A1_values, extent=[min(d2_values), max(d2_values), min(d1_values), max(d1_values)], aspect='auto', cmap=cmap, norm=norm)
plt.colorbar(label='Value of A1')
plt.xlabel('d2')
plt.ylabel('d1')
plt.title('Population of A1 after 365 days')

plt.subplot(1, 2, 2)
plt.imshow(last_A2_values, extent=[min(d2_values), max(d2_values), min(d1_values), max(d1_values)], aspect='auto', cmap=cmap, norm=norm)
plt.colorbar(label='Value of A2')
plt.xlabel('d2')
plt.ylabel('d1')
plt.title('Population of A2 after 365 days')

plt.tight_layout()
plt.show()

# %%
# Define range of alpha1 and alpha3 values
alpha1_values = np.linspace(0.0001, 0.002, 10)
alpha3_values = np.linspace(0.0001, 0.002, 10)

# Initialize arrays to store last values of A1 and A2
last_A1_values = np.zeros((len(alpha1_values), len(alpha3_values)))
last_A2_values = np.zeros((len(alpha1_values), len(alpha3_values)))

# Loop over d1 and d2 values
for i, alpha1 in enumerate(alpha1_values):
    for j, alpha3 in enumerate(alpha3_values):
        # Define initial conditions
        init_conditions = [0, 0, 0, 0, 10000, 0, 0, 0, 0, 0, 10000, 1, 0, 0, 0, 0]

        # Define time parameters
        STARTTIME = 0
        STOPTIME = 365
        DT = 0.02
        num_steps = int((STOPTIME - STARTTIME) / DT)

        # Time integration using RK4
        t_values = np.linspace(STARTTIME, STOPTIME, num_steps+1)
        y_values = np.zeros((num_steps+1, len(init_conditions)))
        t_values[0] = STARTTIME
        y_values[0] = init_conditions
        for step in range(num_steps):
            t = t_values[step]
            y = y_values[step]
            y_next = rk4(model, t, y, DT)
            t_values[step+1] = t + DT
            y_values[step+1] = y_next

        # Store last values of A1 and A2
        last_A1_values[i, j] = y_values[-1, 4]
        last_A2_values[i, j] = y_values[-1, 10]

# Determine the maximum and minimum values for the color bar
vmin = min(np.min(last_A1_values), np.min(last_A2_values))
vmax = max(np.max(last_A1_values), np.max(last_A2_values))

# Create normalization object
norm = Normalize(vmin=vmin, vmax=vmax)

# Choose a colormap
cmap = 'Accent'

# Create heatmaps with the same color bar
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.imshow(last_A1_values, extent=[min(alpha3_values), max(alpha3_values), min(alpha1_values), max(alpha1_values)], aspect='auto', cmap=cmap, norm=norm)
plt.colorbar(label='Last Value of A1')
plt.xlabel('alpha3')
plt.ylabel('alpha1')
plt.title('Heatmap of Last Value of A1')

plt.subplot(1, 2, 2)
plt.imshow(last_A2_values, extent=[min(alpha3_values), max(alpha3_values), min(alpha1_values), max(alpha1_values)], aspect='auto', cmap=cmap, norm=norm)
plt.colorbar(label='Last Value of A2')
plt.xlabel('alpha3')
plt.ylabel('alpha1')
plt.title('Heatmap of Last Value of A2')

plt.tight_layout()
plt.show()

# %%
# Define range of d2 and gamma2 values
d2_values = np.linspace(0.001, 0.01, 10)
gamma2_values = np.linspace(0.5, 1.0, 10)

# Initialize array to store last values of A1 and A2
last_A1_values = np.zeros((len(d2_values), len(gamma2_values)))
last_A2_values = np.zeros((len(d2_values), len(gamma2_values)))

# Loop over d2 and gamma2 values
for i, d2 in enumerate(d2_values):
    for j, gamma2 in enumerate(gamma2_values):
        # Define initial conditions
        init_conditions = [0, 0, 0, 0, 10000, 0, 0, 0, 0, 0, 10000, 1, 0, 0, 0, 0]

        # Define time parameters
        STARTTIME = 0
        STOPTIME = 365
        DT = 0.02
        num_steps = int((STOPTIME - STARTTIME) / DT)

        # Time integration using RK4
        t_values = np.linspace(STARTTIME, STOPTIME, num_steps+1)
        y_values = np.zeros((num_steps+1, len(init_conditions)))
        t_values[0] = STARTTIME
        y_values[0] = init_conditions
        for step in range(num_steps):
            t = t_values[step]
            y = y_values[step]
            y_next = rk4(model, t, y, DT)
            t_values[step+1] = t + DT
            y_values[step+1] = y_next

        # Store last values of A1 and A2
        last_A1_values[i, j] = y_values[-1, 4]
        last_A2_values[i, j] = y_values[-1, 10]
    
# Determine the maximum and minimum values for the color bar
vmin = min(np.min(last_A1_values), np.min(last_A2_values))
vmax = max(np.max(last_A1_values), np.max(last_A2_values))

# Create normalization object
norm = Normalize(vmin=vmin, vmax=vmax)

# Choose a colormap
cmap = 'Accent'  # Change this to the desired colormap

# Create heatmaps with the same color bar
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.imshow(last_A1_values, extent=[min(gamma2_values), max(gamma2_values), min(d2_values), max(d2_values)], aspect='auto', cmap=cmap, norm=norm)
plt.colorbar(label='Last Value of A1')
plt.xlabel('gamma2')
plt.ylabel('d2')
plt.title('Heatmap of Last Value of A1')

plt.subplot(1, 2, 2)
plt.imshow(last_A2_values, extent=[min(gamma2_values), max(gamma2_values), min(d2_values), max(d2_values)], aspect='auto', cmap=cmap, norm=norm)
plt.colorbar(label='Last Value of A2')
plt.xlabel('gamma2')
plt.ylabel('d2')
plt.title('Heatmap of Last Value of A2')

plt.tight_layout()
plt.show()
